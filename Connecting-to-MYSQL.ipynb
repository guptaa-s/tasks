# %%
#TASK
#INSERT THE UCI Carbon Nanotube data in Mysql Workbench

# %%
import pandas as pd
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00448/carbon_nanotubes.csv",sep=';')
df
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
import mysql.connector as connection
def show_databases():
    try:
        mydb=connection.connect(host="localhost", user="root", passwd="", use_pure=True)
        query="SHOW DATABASES"
        cursor=mydb.cursor()
        cursor.execute(query)
        print(cursor.fetchall())
    except Exception as e:
        mydb.close()
        print(str(e))

def create_database(databasename):
    try:
        mydb=connection.connect(host="localhost", user="root", passwd="", use_pure=True)
        query="CREATE DATABASE {}".format(databasename)
        cursor=mydb.cursor()
        cursor.execute(query)
        print("Database created")
    except Exception as e:
        mydb.close()
        print(str(e))

def create_table(databasename,tablename,var):
    try:
        mydb=connection.connect(host="localhost",database=databasename, user="root", passwd="", use_pure=True)
        query="CREATE TABLE {} {}".format(tablename,var)
        cursor=mydb.cursor()
        cursor.execute(query)
        print("Table created")
    except Exception as e:
        mydb.close()
        print(str(e))
        
def insert_values(databasename,tablename,val):
    try:
        mydb=connection.connect(host="localhost",database=databasename, user="root", passwd="", use_pure=True)
        query="INSERT INTO {} VALUES {}".format(tablename,val)
        cursor=mydb.cursor()
        cursor.execute(query)
        mydb.commit()
        print("VALUE INSERTED")
    except Exception as e:
        mydb.close()
        print(str(e))

# %%
show_databases()
# Out:
# [('college',), ('glassdata1',), ('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sales',), ('student1',), ('sys',), ('world',)]

# %%
create_database("carbon")
# Out:
# Database created

# %%
create_table("carbon","UCI_carbon","(Chiral_indice_n INT,Chiral_indice_m INT,Initial_atomic_coordinate_u VARCHAR(20),Initial_atomic_coordinate_v VARCHAR(20),Initial_atomic_coordinate_w VARCHAR(20),Calculated_atomic_coordinates_x VARCHAR(20),Calculated_atomic_coordinates_y VARCHAR(20),Calculated_atomic_coordinates_z VARCHAR(20))")
# Out:
# Table created

# %%
for i in range(0,len(df)):
    st=str(list(df.iloc[i])).replace('[','')
    st1=st.replace(']','')
    insert_values("carbon","UCI_carbon","({})".format(st1))
# Out:
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# VALUE INSERTED
# ...
